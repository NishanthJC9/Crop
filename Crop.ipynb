# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/karnataka_crop_dataset_V2.csv')

# %%
df.head()
# Out:
#         N      P       K  temperature  humidity    ph  rainfall soil_type  \
# 0   18.75  41.30   40.00        26.92     79.07  6.54    404.90     Loamy
# 1  117.04  29.13  103.92        24.60     51.22  6.17    132.64     Loamy
# 2   20.99  21.40   30.00        22.64     59.01  5.58    212.19       Red
# 3   19.89  46.24   24.29        27.99     53.42  6.51    212.80     Black
# 4   53.96  35.99   72.38        33.89     70.89  6.72    148.91     Sandy
#
#    season     district           region      label
# 0  Kharif       Hassan           Malnad  blackgram
# 1    Rabi   Ramanagara  South Karnataka      mango
# 2    Rabi     Tumakuru  South Karnataka  horsegram
# 3    Rabi      Koppala  North Karnataka   chickpea
# 4    Zaid  Chitradurga  South Karnataka     sapota

# %%
x = df[['N','P','K','temperature','humidity','ph','rainfall']]
y = df[['label']]

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# soil_type      0
# season         0
# district       0
# region         0
# label          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(max_depth=15)
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=15)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8747723132969034

# %%
import seaborn as sns

# %%
sns.boxplot(x)
# Out:
# <Axes: >
